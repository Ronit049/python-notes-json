# %%
def make_multi(n):
    def multiply(x):
        return x * n
    return multiply
double = make_multi(2)
triiple = make_multi(3)

print(double(5))
print(triiple(5))
print(double(triiple(2)))
# Out:
# 10
# 15
# 12

# %%
def shout(func):
    def wrapper (*args):
        result = func(*args)
        return result.upper()

# %%
name = "Ronit"
score = 87.8776
rank = 3

print(f'{name:>10}')
print(f'{name:<10}')
print(f'{score:.2f}')
print(f'{score:08.2f}')
print(f'{rank:03d}')
# print(f'{}')
# print(f'{}')
# Out:
#      Ronit
# Ronit
# 87.88
# 00087.88
# 003
